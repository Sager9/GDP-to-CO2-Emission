# %%
from config import Energy_Key
import json


import hvplot.pandas
import pandas as pd
import requests
import time
from scipy.stats import linregress
from matplotlib import pyplot as plt

# %%
key = 'api_key='+Energy_Key

# %%
url = 'https://api.eia.gov/v2/co2-emissions/co2-emissions-aggregates/data/?'+key+'&frequency=annual&data[0]=value&facets[stateId][]=AK&facets[stateId][]=AL&facets[stateId][]=AR&facets[stateId][]=AZ&facets[stateId][]=CA&facets[stateId][]=CO&facets[stateId][]=CT&facets[stateId][]=DC&facets[stateId][]=DE&facets[stateId][]=FL&facets[stateId][]=GA&facets[stateId][]=HI&facets[stateId][]=IA&facets[stateId][]=ID&facets[stateId][]=IL&facets[stateId][]=IN&facets[stateId][]=KS&facets[stateId][]=KY&facets[stateId][]=LA&facets[stateId][]=MA&facets[stateId][]=MD&facets[stateId][]=ME&facets[stateId][]=MI&facets[stateId][]=MN&facets[stateId][]=MO&facets[stateId][]=MS&facets[stateId][]=MT&facets[stateId][]=NC&facets[stateId][]=ND&facets[stateId][]=NE&facets[stateId][]=NH&facets[stateId][]=NJ&facets[stateId][]=NM&facets[stateId][]=NV&facets[stateId][]=NY&facets[stateId][]=OH&facets[stateId][]=OK&facets[stateId][]=OR&facets[stateId][]=PA&facets[stateId][]=RI&facets[stateId][]=SC&facets[stateId][]=SD&facets[stateId][]=TN&facets[stateId][]=TX&facets[stateId][]=US&facets[stateId][]=UT&facets[stateId][]=VA&facets[stateId][]=VT&facets[stateId][]=WA&facets[stateId][]=WI&facets[stateId][]=WV&facets[stateId][]=WY&facets[fuelId][]=TO&facets[sectorId][]=TT&start=2015&end=2015&sort[0][column]=value&sort[0][direction]=asc&offset=0&length=5000'

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
data = response.json()

# %%
data
# Out:
# {'response': {'total': 52,
#   'dateFormat': 'YYYY',
#   'frequency': 'annual',
#   'data': [{'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'DC',
#     'state-name': 'District of Columbia',
#     'value': 2.956881,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'VT',
#     'state-name': 'Vermont',
#     'value': 6.126831,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'RI',
#     'state-name': 'Rhode Island',
#     'value': 10.804525,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'DE',
#     'state-name': 'Delaware',
#     'value': 13.905395,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'SD',
#     'state-name': 'South Dakota',
#     'value': 14.139438,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'NH',
#     'state-name': 'New Hampshire',
#     'value': 15.278567,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'ME',
#     'state-name': 'Maine',
#     'value': 16.679089,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'ID',
#     'state-name': 'Idaho',
#     'value': 18.035914,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'HI',
#     'state-name': 'Hawaii',
#     'value': 19.781037,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'MT',
#     'state-name': 'Montana',
#     'value': 32.531645,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'AK',
#     'state-name': 'Alaska',
#     'value': 35.027804,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'CT',
#     'state-name': 'Connecticut',
#     'value': 36.329049,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'OR',
#     'state-name': 'Oregon',
#     'value': 37.894168,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'NV',
#     'state-name': 'Nevada',
#     'value': 38.517135,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'NM',
#     'state-name': 'New Mexico',
#     'value': 50.691832,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'NE',
#     'state-name': 'Nebraska',
#     'value': 50.710576,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'ND',
#     'state-name': 'North Dakota',
#     'value': 57.92306,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'AR',
#     'state-name': 'Arkansas',
#     'value': 59.053365,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'MS',
#     'state-name': 'Mississippi',
#     'value': 61.296921,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'MD',
#     'state-name': 'Maryland',
#     'value': 62.280327,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'UT',
#     'state-name': 'Utah',
#     'value': 63.613022,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'WY',
#     'state-name': 'Wyoming',
#     'value': 64.092863,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'KS',
#     'state-name': 'Kansas',
#     'value': 64.51256,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'MA',
#     'state-name': 'Massachusetts',
#     'value': 66.746522,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'SC',
#     'state-name': 'South Carolina',
#     'value': 73.398806,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'WA',
#     'state-name': 'Washington',
#     'value': 75.137115,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'IA',
#     'state-name': 'Iowa',
#     'value': 77.41574,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'MN',
#     'state-name': 'Minnesota',
#     'value': 89.330999,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'CO',
#     'state-name': 'Colorado',
#     'value': 91.303872,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'WV',
#     'state-name': 'West Virginia',
#     'value': 91.963078,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'AZ',
#     'state-name': 'Arizona',
#     'value': 94.978784,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'TN',
#     'state-name': 'Tennessee',
#     'value': 98.703926,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'WI',
#     'state-name': 'Wisconsin',
#     'value': 99.857015,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'OK',
#     'state-name': 'Oklahoma',
#     'value': 100.288331,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'NJ',
#     'state-name': 'New Jersey',
#     'value': 103.66,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'VA',
#     'state-name': 'Virginia',
#     'value': 107.619904,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'AL',
#     'state-name': 'Alabama',
#     'value': 119.200889,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'MO',
#     'state-name': 'Missouri',
#     'value': 124.747331,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'NC',
#     'state-name': 'North Carolina',
#     'value': 124.778284,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'KY',
#     'state-name': 'Kentucky',
#     'value': 131.34297,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'GA',
#     'state-name': 'Georgia',
#     'value': 145.675638,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'MI',
#     'state-name': 'Michigan',
#     'value': 164.455623,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'NY',
#     'state-name': 'New York',
#     'value': 174.359924,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'LA',
#     'state-name': 'Louisiana',
#     'value': 185.559256,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'IN',
#     'state-name': 'Indiana',
#     'value': 187.233514,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'OH',
#     'state-name': 'Ohio',
#     'value': 211.196625,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'IL',
#     'state-name': 'Illinois',
#     'value': 219.157681,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'PA',
#     'state-name': 'Pennsylvania',
#     'value': 232.925227,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'FL',
#     'state-name': 'Florida',
#     'value': 237.383359,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'CA',
#     'state-name': 'California',
#     'value': 351.408516,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'TX',
#     'state-name': 'Texas',
#     'value': 655.143227,
#     'value-units': 'million metric tons of CO2'},
#    {'period': 2015,
#     'sectorId': 'TT',
#     'sector-name': 'Total carbon dioxide emissions from all sectors',
#     'fuelId': 'TO',
#     'fuel-name': 'All Fuels',
#     'stateId': 'US',
#     'state-name': 'United States',
#     'value': 5267.153266,
#     'value-units': 'million metric tons of CO2'}],
#   'description': 'CO2 emission aggregates by fuel, state, and sector.  Report and documentation: https://www.eia.gov/environment/emissions/state/'},
#  'request': {'command': '/v2/co2-emissions/co2-emissions-aggregates/data/',
#   'params': {'api_key': 'KObxN95MIdTOBOo0NgeD02OgsBGxsbeQ9yKQqugs',
#    'frequency': 'annual',
#    'data': ['value'],
#    'facets': {'stateId': ['AK',
#      'AL',
#      'AR',
#      'AZ',
#      'CA',
#      'CO',
#      'CT',
#      'DC',
#      'DE',
#      'FL',
#      'GA',
#      'HI',
#      'IA',
#      'ID',
#      'IL',
#      'IN',
#      'KS',
#      'KY',
#      'LA',
#      'MA',
#      'MD',
#      'ME',
#      'MI',
#      'MN',
#      'MO',
#      'MS',
#      'MT',
#      'NC',
#      'ND',
#      'NE',
#      'NH',
#      'NJ',
#      'NM',
#      'NV',
#      'NY',
#      'OH',
#      'OK',
#      'OR',
#      'PA',
#      'RI',
#      'SC',
#      'SD',
#      'TN',
#      'TX',
#      'US',
#      'UT',
#      'VA',
#      'VT',
#      'WA',
#      'WI',
#      'WV',
#      'WY'],
#     'fuelId': ['TO'],
#     'sectorId': ['TT']},
#    'start': 2015,
#    'end': 2015,
#    'sort': [{'column': 'value', 'direction': 'asc'}],
#    'offset': 0,
#    'length': 5000}},
#  'apiVersion': '2.1.4'}

# %%
data['response']['data'][1]['stateId']
# Out:
# 'VT'

# %%
state = []
emissions = []
x = 0

# %%
while x < 52:
    state.append(data['response']['data'][x]['state-name'])
    emissions.append(data['response']['data'][x]['value'])
    x = x+1

# %%
df = pd.DataFrame(list(zip(state, emissions)), columns =['State', 'million metric tons of CO2'])
df
# Out:
#                    State  million metric tons of CO2
# 0   District of Columbia                    2.956881
# 1                Vermont                    6.126831
# 2           Rhode Island                   10.804525
# 3               Delaware                   13.905395
# 4           South Dakota                   14.139438
# 5          New Hampshire                   15.278567
# 6                  Maine                   16.679089
# 7                  Idaho                   18.035914
# 8                 Hawaii                   19.781037
# 9                Montana                   32.531645
# 10                Alaska                   35.027804
# 11           Connecticut                   36.329049
# 12                Oregon                   37.894168
# 13                Nevada                   38.517135
# 14            New Mexico                   50.691832
# 15              Nebraska                   50.710576
# 16          North Dakota                   57.923060
# 17              Arkansas                   59.053365
# 18           Mississippi                   61.296921
# 19              Maryland                   62.280327
# 20                  Utah                   63.613022
# 21               Wyoming                   64.092863
# 22                Kansas                   64.512560
# 23         Massachusetts                   66.746522
# 24        South Carolina                   73.398806
# 25            Washington                   75.137115
# 26                  Iowa                   77.415740
# 27             Minnesota                   89.330999
# 28              Colorado                   91.303872
# 29         West Virginia                   91.963078
# 30               Arizona                   94.978784
# 31             Tennessee                   98.703926
# 32             Wisconsin                   99.857015
# 33              Oklahoma                  100.288331
# 34            New Jersey                  103.660000
# 35              Virginia                  107.619904
# 36               Alabama                  119.200889
# 37              Missouri                  124.747331
# 38        North Carolina                  124.778284
# 39              Kentucky                  131.342970
# 40               Georgia                  145.675638
# 41              Michigan                  164.455623
# 42              New York                  174.359924
# 43             Louisiana                  185.559256
# 44               Indiana                  187.233514
# 45                  Ohio                  211.196625
# 46              Illinois                  219.157681
# 47          Pennsylvania                  232.925227
# 48               Florida                  237.383359
# 49            California                  351.408516
# 50                 Texas                  655.143227
# 51         United States                 5267.153266

# %%
emmisions_s = df.sort_values(by=['State'])
clean_emmisions = emmisions_s.reset_index(drop=True)
clean_emmisions
# Out:
#                    State  million metric tons of CO2
# 0                Alabama                  119.200889
# 1                 Alaska                   35.027804
# 2                Arizona                   94.978784
# 3               Arkansas                   59.053365
# 4             California                  351.408516
# 5               Colorado                   91.303872
# 6            Connecticut                   36.329049
# 7               Delaware                   13.905395
# 8   District of Columbia                    2.956881
# 9                Florida                  237.383359
# 10               Georgia                  145.675638
# 11                Hawaii                   19.781037
# 12                 Idaho                   18.035914
# 13              Illinois                  219.157681
# 14               Indiana                  187.233514
# 15                  Iowa                   77.415740
# 16                Kansas                   64.512560
# 17              Kentucky                  131.342970
# 18             Louisiana                  185.559256
# 19                 Maine                   16.679089
# 20              Maryland                   62.280327
# 21         Massachusetts                   66.746522
# 22              Michigan                  164.455623
# 23             Minnesota                   89.330999
# 24           Mississippi                   61.296921
# 25              Missouri                  124.747331
# 26               Montana                   32.531645
# 27              Nebraska                   50.710576
# 28                Nevada                   38.517135
# 29         New Hampshire                   15.278567
# 30            New Jersey                  103.660000
# 31            New Mexico                   50.691832
# 32              New York                  174.359924
# 33        North Carolina                  124.778284
# 34          North Dakota                   57.923060
# 35                  Ohio                  211.196625
# 36              Oklahoma                  100.288331
# 37                Oregon                   37.894168
# 38          Pennsylvania                  232.925227
# 39          Rhode Island                   10.804525
# 40        South Carolina                   73.398806
# 41          South Dakota                   14.139438
# 42             Tennessee                   98.703926
# 43                 Texas                  655.143227
# 44         United States                 5267.153266
# 45                  Utah                   63.613022
# 46               Vermont                    6.126831
# 47              Virginia                  107.619904
# 48            Washington                   75.137115
# 49         West Virginia                   91.963078
# 50             Wisconsin                   99.857015
# 51               Wyoming                   64.092863

# %%
gdp_csv = pd.read_csv('2015_GDP.csv')
gdp_csv_s = gdp_csv.sort_values(by=['GeoName'])
clean_gdp = gdp_csv_s[['GeoName','2015']]
clean_gdp_r = clean_gdp.rename(columns={"GeoName":"State",'2015':"GDP in Millions"})
clean_gdp_r
# Out:
#                    State  GDP in Millions
# 1                Alabama         202372.4
# 2                 Alaska          51490.9
# 3                Arizona         299393.3
# 4               Arkansas         117786.8
# 5             California        2473555.9
# 6               Colorado         320721.1
# 7            Connecticut         259487.8
# 8               Delaware          71913.9
# 9   District of Columbia         124604.7
# 10               Florida         908519.9
# 11               Georgia         521008.2
# 12                Hawaii          81230.3
# 13                 Idaho          65899.9
# 14              Illinois         799930.5
# 15               Indiana         331945.7
# 16                  Iowa         180299.3
# 17                Kansas         154958.2
# 18              Kentucky         193413.1
# 19             Louisiana         235113.5
# 20                 Maine          58131.3
# 21              Maryland         369728.1
# 22         Massachusetts         498851.3
# 23              Michigan         474983.3
# 24             Minnesota         335530.2
# 25           Mississippi         105914.6
# 26              Missouri         296929.3
# 27               Montana          46604.1
# 28              Nebraska         116514.6
# 29                Nevada         145115.9
# 30         New Hampshire          76478.0
# 31            New Jersey         563233.8
# 32            New Mexico          90274.3
# 33              New York        1487627.6
# 34        North Carolina         508928.7
# 35          North Dakota          55996.9
# 36                  Ohio         611019.5
# 37              Oklahoma         186815.6
# 38                Oregon         200659.6
# 39          Pennsylvania         714202.9
# 40          Rhode Island          56390.8
# 41        South Carolina         205816.7
# 42          South Dakota          48070.2
# 43             Tennessee         325294.0
# 44                 Texas        1573498.4
# 0          United States       18206023.0
# 45                  Utah         149153.4
# 46               Vermont          30933.3
# 47              Virginia         483786.5
# 48            Washington         466689.7
# 49         West Virginia          71318.5
# 50             Wisconsin         307507.9
# 51               Wyoming          38426.9

# %%
finial = clean_gdp_r.merge(clean_emmisions, on='State')
finial
# Out:
#                    State  GDP in Millions  million metric tons of CO2
# 0                Alabama         202372.4                  119.200889
# 1                 Alaska          51490.9                   35.027804
# 2                Arizona         299393.3                   94.978784
# 3               Arkansas         117786.8                   59.053365
# 4             California        2473555.9                  351.408516
# 5               Colorado         320721.1                   91.303872
# 6            Connecticut         259487.8                   36.329049
# 7               Delaware          71913.9                   13.905395
# 8   District of Columbia         124604.7                    2.956881
# 9                Florida         908519.9                  237.383359
# 10               Georgia         521008.2                  145.675638
# 11                Hawaii          81230.3                   19.781037
# 12                 Idaho          65899.9                   18.035914
# 13              Illinois         799930.5                  219.157681
# 14               Indiana         331945.7                  187.233514
# 15                  Iowa         180299.3                   77.415740
# 16                Kansas         154958.2                   64.512560
# 17              Kentucky         193413.1                  131.342970
# 18             Louisiana         235113.5                  185.559256
# 19                 Maine          58131.3                   16.679089
# 20              Maryland         369728.1                   62.280327
# 21         Massachusetts         498851.3                   66.746522
# 22              Michigan         474983.3                  164.455623
# 23             Minnesota         335530.2                   89.330999
# 24           Mississippi         105914.6                   61.296921
# 25              Missouri         296929.3                  124.747331
# 26               Montana          46604.1                   32.531645
# 27              Nebraska         116514.6                   50.710576
# 28                Nevada         145115.9                   38.517135
# 29         New Hampshire          76478.0                   15.278567
# 30            New Jersey         563233.8                  103.660000
# 31            New Mexico          90274.3                   50.691832
# 32              New York        1487627.6                  174.359924
# 33        North Carolina         508928.7                  124.778284
# 34          North Dakota          55996.9                   57.923060
# 35                  Ohio         611019.5                  211.196625
# 36              Oklahoma         186815.6                  100.288331
# 37                Oregon         200659.6                   37.894168
# 38          Pennsylvania         714202.9                  232.925227
# 39          Rhode Island          56390.8                   10.804525
# 40        South Carolina         205816.7                   73.398806
# 41          South Dakota          48070.2                   14.139438
# 42             Tennessee         325294.0                   98.703926
# 43                 Texas        1573498.4                  655.143227
# 44         United States       18206023.0                 5267.153266
# 45                  Utah         149153.4                   63.613022
# 46               Vermont          30933.3                    6.126831
# 47              Virginia         483786.5                  107.619904
# 48            Washington         466689.7                   75.137115
# 49         West Virginia          71318.5                   91.963078
# 50             Wisconsin         307507.9                   99.857015
# 51               Wyoming          38426.9                   64.092863

# %%
finial.plot.scatter(y='GDP in Millions',
                      x='million metric tons of CO2')
# Out:
# <Axes: xlabel='GDP in Millions', ylabel='million metric tons of CO2'>

# %%
finial_states = finial.drop(finial.index[44])
finial_states
# Out:
#                    State  GDP in Millions  million metric tons of CO2
# 0                Alabama         202372.4                  119.200889
# 1                 Alaska          51490.9                   35.027804
# 2                Arizona         299393.3                   94.978784
# 3               Arkansas         117786.8                   59.053365
# 4             California        2473555.9                  351.408516
# 5               Colorado         320721.1                   91.303872
# 6            Connecticut         259487.8                   36.329049
# 7               Delaware          71913.9                   13.905395
# 8   District of Columbia         124604.7                    2.956881
# 9                Florida         908519.9                  237.383359
# 10               Georgia         521008.2                  145.675638
# 11                Hawaii          81230.3                   19.781037
# 12                 Idaho          65899.9                   18.035914
# 13              Illinois         799930.5                  219.157681
# 14               Indiana         331945.7                  187.233514
# 15                  Iowa         180299.3                   77.415740
# 16                Kansas         154958.2                   64.512560
# 17              Kentucky         193413.1                  131.342970
# 18             Louisiana         235113.5                  185.559256
# 19                 Maine          58131.3                   16.679089
# 20              Maryland         369728.1                   62.280327
# 21         Massachusetts         498851.3                   66.746522
# 22              Michigan         474983.3                  164.455623
# 23             Minnesota         335530.2                   89.330999
# 24           Mississippi         105914.6                   61.296921
# 25              Missouri         296929.3                  124.747331
# 26               Montana          46604.1                   32.531645
# 27              Nebraska         116514.6                   50.710576
# 28                Nevada         145115.9                   38.517135
# 29         New Hampshire          76478.0                   15.278567
# 30            New Jersey         563233.8                  103.660000
# 31            New Mexico          90274.3                   50.691832
# 32              New York        1487627.6                  174.359924
# 33        North Carolina         508928.7                  124.778284
# 34          North Dakota          55996.9                   57.923060
# 35                  Ohio         611019.5                  211.196625
# 36              Oklahoma         186815.6                  100.288331
# 37                Oregon         200659.6                   37.894168
# 38          Pennsylvania         714202.9                  232.925227
# 39          Rhode Island          56390.8                   10.804525
# 40        South Carolina         205816.7                   73.398806
# 41          South Dakota          48070.2                   14.139438
# 42             Tennessee         325294.0                   98.703926
# 43                 Texas        1573498.4                  655.143227
# 45                  Utah         149153.4                   63.613022
# 46               Vermont          30933.3                    6.126831
# 47              Virginia         483786.5                  107.619904
# 48            Washington         466689.7                   75.137115
# 49         West Virginia          71318.5                   91.963078
# 50             Wisconsin         307507.9                   99.857015
# 51               Wyoming          38426.9                   64.092863

# %%
finial_states.plot.scatter(y='GDP in Millions',
                      x='million metric tons of CO2')
# Out:
# <Axes: xlabel='million metric tons of CO2', ylabel='GDP in Millions'>
